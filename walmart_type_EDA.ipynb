# %%
# %matplotlib inline

# %%
train = pd.read_csv('C:\\dss\\team_project2\\walmart\\train.csv')
train
# Out:
#         TripType  VisitNumber Weekday           Upc  ScanCount  \
# 0            999            5  Friday  6.811315e+10         -1
# 1             30            7  Friday  6.053882e+10          1
# 2             30            7  Friday  7.410811e+09          1
# 3             26            8  Friday  2.238404e+09          2
# 4             26            8  Friday  2.006614e+09          2
# 5             26            8  Friday  2.006619e+09          2
# 6             26            8  Friday  2.006614e+09          1
# 7             26            8  Friday  7.004803e+09          1
# 8             26            8  Friday  2.238495e+09          1
# 9             26            8  Friday  2.238400e+09         -1
# 10            26            8  Friday  5.200010e+09          1
# 11            26            8  Friday  8.867930e+10          2
# 12            26            8  Friday  2.200600e+10          1
# 13            26            8  Friday  2.236760e+09          1
# 14            26            8  Friday  8.867930e+10         -1
# 15            26            8  Friday  2.238400e+09          2
# 16            26            8  Friday  3.019294e+09          1
# 17            26            8  Friday  7.245041e+10          1
# 18            26            8  Friday  2.554150e+10          2
# 19            26            8  Friday  2.310011e+09          1
# 20            26            8  Friday  7.245040e+10          2
# 21            26            8  Friday  7.874205e+09          1
# 22            26            8  Friday  5.114139e+09          1
# 23            26            8  Friday  5.114198e+09          1
# 24            26            8  Friday  3.270011e+09          3
# 25            26            8  Friday           NaN          1
# 26             8            9  Friday  1.070081e+09          1
# 27             8            9  Friday  3.107000e+03          1
# 28             8            9  Friday  4.011000e+03          1
# 29             8           10  Friday  6.414410e+09          1
# ...          ...          ...     ...           ...        ...
# 647024        39       191345  Sunday  3.800405e+10          2
# 647025        39       191345  Sunday  3.890003e+09          1
# 647026        39       191345  Sunday  3.890003e+09          1
# 647027        39       191345  Sunday  7.225004e+09          1
# 647028        39       191345  Sunday  7.800001e+09          1
# 647029        39       191345  Sunday  1.380310e+09          1
# 647030        39       191345  Sunday  4.812129e+09          2
# 647031        39       191345  Sunday  3.029939e+10          1
# 647032        39       191345  Sunday  3.010078e+09          2
# 647033        39       191345  Sunday  7.286800e+09          1
# 647034        39       191345  Sunday  3.700088e+09          1
# 647035        39       191346  Sunday  3.760012e+09          1
# 647036        39       191346  Sunday  3.338365e+09          1
# 647037        39       191346  Sunday  4.150000e+09          1
# 647038        39       191346  Sunday  1.340952e+09          1
# 647039        39       191346  Sunday  7.874223e+09          1
# 647040        39       191346  Sunday  3.700046e+09          1
# 647041        39       191346  Sunday  5.440000e+09          1
# 647042        39       191346  Sunday  2.265572e+09          1
# 647043        39       191346  Sunday  3.660230e+09          1
# 647044        39       191346  Sunday  5.100020e+09          1
# 647045        39       191346  Sunday  7.874204e+09          1
# 647046        39       191346  Sunday  3.120020e+09          1
# 647047        39       191346  Sunday  3.120033e+09          1
# 647048        39       191346  Sunday  3.700091e+09          1
# 647049        39       191346  Sunday  3.239000e+10          1
# 647050        39       191346  Sunday  7.874205e+09          1
# 647051        39       191346  Sunday  4.072000e+03          1
# 647052         8       191347  Sunday  4.190008e+09          1
# 647053         8       191347  Sunday  3.800060e+09          1
#
#            DepartmentDescription  FinelineNumber
# 0             FINANCIAL SERVICES          1000.0
# 1                          SHOES          8931.0
# 2                  PERSONAL CARE          4504.0
# 3          PAINT AND ACCESSORIES          3565.0
# 4          PAINT AND ACCESSORIES          1017.0
# 5          PAINT AND ACCESSORIES          1017.0
# 6          PAINT AND ACCESSORIES          1017.0
# 7          PAINT AND ACCESSORIES          2802.0
# 8          PAINT AND ACCESSORIES          4501.0
# 9          PAINT AND ACCESSORIES          3565.0
# 10                   DSD GROCERY          4606.0
# 11         PAINT AND ACCESSORIES          3504.0
# 12         MEAT - FRESH & FROZEN          6009.0
# 13         PAINT AND ACCESSORIES             7.0
# 14         PAINT AND ACCESSORIES          3504.0
# 15         PAINT AND ACCESSORIES          3565.0
# 16         PAINT AND ACCESSORIES          2801.0
# 17         PAINT AND ACCESSORIES          1028.0
# 18                         DAIRY          1305.0
# 19             PETS AND SUPPLIES          3300.0
# 20         PAINT AND ACCESSORIES          1018.0
# 21      HOUSEHOLD CHEMICALS/SUPP           707.0
# 22         PAINT AND ACCESSORIES          4415.0
# 23         PAINT AND ACCESSORIES          4415.0
# 24             PETS AND SUPPLIES          1001.0
# 25                           NaN             NaN
# 26           IMPULSE MERCHANDISE           115.0
# 27                       PRODUCE           103.0
# 28                       PRODUCE          5501.0
# 29                   DSD GROCERY          2008.0
# ...                          ...             ...
# 647024              PHARMACY OTC          5532.0
# 647025         GROCERY DRY GOODS          2764.0
# 647026         GROCERY DRY GOODS          2764.0
# 647027                COMM BREAD          3702.0
# 647028               DSD GROCERY          9513.0
# 647029               ELECTRONICS          1266.0
# 647030                COMM BREAD          3719.0
# 647031                    BEAUTY          4503.0
# 647032               DSD GROCERY          3903.0
# 647033  HOUSEHOLD CHEMICALS/SUPP          3510.0
# 647034     HOUSEHOLD PAPER GOODS          1006.0
# 647035         GROCERY DRY GOODS          1104.0
# 647036                   PRODUCE          7601.0
# 647037         GROCERY DRY GOODS          2302.0
# 647038         GROCERY DRY GOODS          2351.0
# 647039               DSD GROCERY          4636.0
# 647040  HOUSEHOLD CHEMICALS/SUPP          8910.0
# 647041         GROCERY DRY GOODS          2409.0
# 647042     MEAT - FRESH & FROZEN          6158.0
# 647043              PHARMACY OTC          1110.0
# 647044         GROCERY DRY GOODS          3107.0
# 647045                     DAIRY          7955.0
# 647046               DSD GROCERY          4639.0
# 647047               DSD GROCERY          4639.0
# 647048  HOUSEHOLD CHEMICALS/SUPP          8947.0
# 647049              PHARMACY OTC          1118.0
# 647050              FROZEN FOODS          1752.0
# 647051                   PRODUCE          4170.0
# 647052                     DAIRY          1512.0
# 647053         GROCERY DRY GOODS          3600.0
#
# [647054 rows x 7 columns]

# %%
test = pd.read_csv('C:\\dss\\team_project2\\walmart\\test.csv')
test
# Out:
#         VisitNumber Weekday           Upc  ScanCount  \
# 0                 1  Friday  7.250339e+10          1
# 9                     PERSONAL CARE          4504.0
# 10               FABRICS AND CRAFTS          5924.0
# 11                        BOYS WEAR           654.0
# 12                        BOYS WEAR           654.0
# 13                  PRE PACKED DELI          7651.0
# 14                      DSD GROCERY          4606.0
# 15                        MENS WEAR          8173.0
# 16                      CELEBRATION             6.0
# 17                      DSD GROCERY          3658.0
# 18              IMPULSE MERCHANDISE           115.0
# 19         HOUSEHOLD CHEMICALS/SUPP          1555.0
# 20                      DSD GROCERY          9513.0
# 21                     FROZEN FOODS          9115.0
# 22                     FROZEN FOODS          9115.0
# 23                        MENS WEAR          8033.0
# 24                      DSD GROCERY          3651.0
# 25                      DSD GROCERY          9570.0
# 26               FABRICS AND CRAFTS          2926.0
# 27                      DSD GROCERY          4005.0
# 28              IMPULSE MERCHANDISE           125.0
# 29                      DSD GROCERY          9570.0
# ...                             ...             ...
# 653616                  DSD GROCERY          9570.0
# 653617                  DSD GROCERY          3004.0
# 653618     HOUSEHOLD CHEMICALS/SUPP          8881.0
# 653619     HOUSEHOLD CHEMICALS/SUPP          8881.0
# 653620     HOUSEHOLD CHEMICALS/SUPP          2040.0
# 653621      CANDY, TOBACCO, COOKIES            19.0
# 653622     HOUSEHOLD CHEMICALS/SUPP           110.0
# 653623          IMPULSE MERCHANDISE           110.0
# 653624        PAINT AND ACCESSORIES          1021.0
# 653625        PAINT AND ACCESSORIES          4007.0
# 653626                   AUTOMOTIVE          4006.0
# 653627          IMPULSE MERCHANDISE           801.0
# 653628          IMPULSE MERCHANDISE           115.0
# 653629     HOUSEHOLD CHEMICALS/SUPP          2070.0
# 653630                   HOME DECOR          5575.0
# 653631     HOUSEHOLD CHEMICALS/SUPP          6010.0
# 653632        HOUSEHOLD PAPER GOODS          2020.0
# 653633  INFANT CONSUMABLE HARDLINES           235.0
# 653634  INFANT CONSUMABLE HARDLINES          2101.0
# 653635  INFANT CONSUMABLE HARDLINES           203.0
# 653636               INFANT APPAREL          6405.0
# 653637  INFANT CONSUMABLE HARDLINES          1009.0
# 653638               INFANT APPAREL          6407.0
# 653639           SWIMWEAR/OUTERWEAR           321.0
# 653640                    MENS WEAR          1857.0
# 653641              BATH AND SHOWER          1505.0
# 653642              BATH AND SHOWER          1099.0
# 653643                    MENS WEAR          8220.0
# 653644           SWIMWEAR/OUTERWEAR           114.0
# 653645                    MENS WEAR          4923.0
#
# [653646 rows x 6 columns]

# %%
train.isna().sum()
# Out:
# TripType                    0
# VisitNumber                 0
# Weekday                     0
# Upc                      4129
# ScanCount                   0
# DepartmentDescription    1361
# FinelineNumber           4129
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647054 entries, 0 to 647053
# Data columns (total 7 columns):
# TripType                 647054 non-null int64
# VisitNumber              647054 non-null int64
# Weekday                  647054 non-null object
# Upc                      642925 non-null float64
# ScanCount                647054 non-null int64
# DepartmentDescription    645693 non-null object
# FinelineNumber           642925 non-null float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 34.6+ MB

# %%
train.describe()
# Out:
#             TripType    VisitNumber           Upc      ScanCount  \
# count  647054.000000  647054.000000  6.429250e+05  647054.000000
# mean       58.584511   96167.640078  3.060698e+10       1.108878
# std       157.635533   55545.485154  9.120134e+10       0.700776
# min         3.000000       5.000000  8.340000e+02     -12.000000
# 25%        27.000000   49268.000000  3.400001e+09       1.000000
# 50%        39.000000   97074.000000  7.050103e+09       1.000000
# 75%        40.000000  144316.000000  3.006531e+10       1.000000
# max       999.000000  191347.000000  9.789707e+11      71.000000
#
#        FinelineNumber
# count   642925.000000
# mean      3726.884567
# std       2780.966158
# min          0.000000
# 25%       1404.000000
# 50%       3352.000000
# 75%       5501.000000
# max       9998.000000

# %%
sns.heatmap(data = train.corr(), annot=True, fmt='.2f', linewidths=5)
plt.show()

# %%
# 전체의 unique와 unique갯수
for i in train.columns:
    print(i, train[i].unique(),'\n' , len(train[i].unique()))
# Out:
# TripType [999  30  26   8  35  41  21   6  42   7   9  39  25  38  15  36  20  37
#   32  40   5   3   4  24  33  43  31  27  34  18  29  44  19  23  22  28
#   14  12]
#  38
# VisitNumber [     5      7      8 ... 191345 191346 191347]
#  95674
# Weekday ['Friday' 'Saturday' 'Sunday' 'Monday' 'Tuesday' 'Wednesday' 'Thursday']
#  7
# Upc [6.81131529e+10 6.05388160e+10 7.41081110e+09 ... 8.85306278e+10
#  8.87439527e+10 5.44000008e+09]
#  97715
# ScanCount [ -1   1   2   3   5   6   4  14  -2   9   7  10   8  -3  -5  11  16  -4
#   13  15  30  -6  12  20 -12  19  46  23  -7  22  25  24  31  -9  51  17
#   18  71 -10]
#  39
# DepartmentDescription ['FINANCIAL SERVICES' 'SHOES' 'PERSONAL CARE' 'PAINT AND ACCESSORIES'
#  'DSD GROCERY' 'MEAT - FRESH & FROZEN' 'DAIRY' 'PETS AND SUPPLIES'
#  'HOUSEHOLD CHEMICALS/SUPP' nan 'IMPULSE MERCHANDISE' 'PRODUCE'
#  'CANDY, TOBACCO, COOKIES' 'GROCERY DRY GOODS' 'BOYS WEAR'
#  'FABRICS AND CRAFTS' 'JEWELRY AND SUNGLASSES' 'MENS WEAR' 'ACCESSORIES'
#  'HOME MANAGEMENT' 'FROZEN FOODS' 'SERVICE DELI'
#  'INFANT CONSUMABLE HARDLINES' 'PRE PACKED DELI' 'COOK AND DINE'
#  'PHARMACY OTC' 'LADIESWEAR' 'COMM BREAD' 'BAKERY' 'HOUSEHOLD PAPER GOODS'
#  'CELEBRATION' 'HARDWARE' 'BEAUTY' 'AUTOMOTIVE' 'BOOKS AND MAGAZINES'
#  'SEAFOOD' 'OFFICE SUPPLIES' 'LAWN AND GARDEN' 'SHEER HOSIERY' 'WIRELESS'
#  'BEDDING' 'BATH AND SHOWER' 'HORTICULTURE AND ACCESS' 'HOME DECOR' 'TOYS'
#  'INFANT APPAREL' 'LADIES SOCKS' 'PLUS AND MATERNITY' 'ELECTRONICS'
#  'GIRLS WEAR, 4-6X  AND 7-14' 'BRAS & SHAPEWEAR' 'LIQUOR,WINE,BEER'
#  'SLEEPWEAR/FOUNDATIONS' 'CAMERAS AND SUPPLIES' 'SPORTING GOODS'
#  'PLAYERS AND ELECTRONICS' 'PHARMACY RX' 'MENSWEAR' 'OPTICAL - FRAMES'
#  'SWIMWEAR/OUTERWEAR' 'OTHER DEPARTMENTS' 'MEDIA AND GAMING' 'FURNITURE'
#  'OPTICAL - LENSES' 'SEASONAL' 'LARGE HOUSEHOLD GOODS' '1-HR PHOTO'
#  'CONCEPT STORES' 'HEALTH AND BEAUTY AIDS']
#  69
# FinelineNumber [1000. 8931. 4504. ... 8257. 4314. 7130.]
#  5196

# %% [markdown]
# ### TripType
# - 어떤 목적을 가지고 왔는지

# %%
train[train["FinelineNumber"] == 999]
# Out:
#         TripType  VisitNumber Weekday           Upc  ScanCount  \
# 0            999            5  Friday  6.811315e+10         -1
# 300          999          133  Friday  9.933894e+09         -1
# 301          999          133  Friday  9.933894e+09          1
# 369          999          182  Friday  5.473282e+09         -1
# 376          999          190  Friday  4.316875e+09         -1
# 399          999          207  Friday  7.616352e+10          1
# 400          999          207  Friday  2.242229e+09          2
# 509          999          253  Friday  6.811318e+10         -1
# 553          999          261  Friday  7.602764e+09         -1
# 590          999          281  Friday  6.811318e+10         -1
# 660          999          295  Friday  1.019906e+09          1
# 709          999          317  Friday  6.053881e+10         -1
# 730          999          333  Friday  6.565145e+10          1
# 731          999          333  Friday  6.565145e+10         -1
# 760          999          351  Friday  6.811318e+10          1
# 761          999          351  Friday  6.811318e+10          1
# 762          999          357  Friday  6.053881e+10          1
# 763          999          357  Friday  6.811311e+10          1
# 945          999          400  Friday  7.548191e+10         -1
# 949          999          403  Friday  6.053881e+10         -1
# 950          999          407  Friday  6.811318e+10         -1
# 959          999          409  Friday           NaN         -1
# 1030         999          436  Friday  6.811315e+10          1
# 1031         999          437  Friday  7.166051e+10         -1
# 1115         999          476  Friday  9.512112e+09          1
# 1134         999          484  Friday           NaN         -2
# 1135         999          484  Friday           NaN         -2
# 1183         999          511  Friday  6.811318e+10          1
# 1184         999          511  Friday  6.811318e+10          1
# 1235         999          540  Friday  6.053881e+10          1
# ...          ...          ...     ...           ...        ...
# 643402       999       190485  Sunday  8.486830e+10         -1
# 643446       999       190502  Sunday  7.314929e+09         -1
# 643447       999       190502  Sunday  7.283831e+09         -1
# 643448       999       190502  Sunday  8.050404e+10         -1
# 643682       999       190571  Sunday  4.087000e+03          1
# 643683       999       190571  Sunday  4.087000e+03         -1
# 643684       999       190571  Sunday  3.338360e+09         -1
# 643685       999       190571  Sunday  3.338360e+09          1
# 643715       999       190582  Sunday  7.993661e+10          1
# 643716       999       190582  Sunday  8.853708e+10          1
# 643717       999       190582  Sunday  7.993661e+10          1
# 643853       999       190624  Sunday  4.238598e+09         -1
# 643940       999       190641  Sunday  9.285205e+09          3
# 643941       999       190641  Sunday  6.811317e+10          1
# 643942       999       190641  Sunday  7.365081e+09          1
# 644680          HOME MANAGEMENT          7101.0
# 644698         BRAS & SHAPEWEAR          2812.0
# 644810                 HARDWARE           381.0
# 645028                  PRODUCE          3004.0
# 645029                  PRODUCE          3004.0
# 645240            PERSONAL CARE          5365.0
# 646341  CANDY, TOBACCO, COOKIES            97.0
# 646342              ELECTRONICS          4110.0
#
# [17590 rows x 7 columns]

# %%
train['TripType'].unique(), len(train['TripType'].unique())
# Out:
# (array([999,  30,  26,   8,  35,  41,  21,   6,  42,   7,   9,  39,  25,
#          38,  15,  36,  20,  37,  32,  40,   5,   3,   4,  24,  33,  43,
#          31,  27,  34,  18,  29,  44,  19,  23,  22,  28,  14,  12],
#        dtype=int64), 38)

# %%
plt.plot(train["TripType"])
plt.show()

# %% [markdown]
# ### Upc

# %%
len(train["Upc"].unique()),train["Upc"].unique()
# Out:
# (97715, array([6.81131529e+10, 6.05388160e+10, 7.41081110e+09, ...,
#         8.85306278e+10, 8.87439527e+10, 5.44000008e+09]))

# %%
plt.scatter(train["Upc"], train["TripType"])
plt.show()

# %%
del train["Upc"]

# %% [markdown]
# ### VisitNumber
# - 방문자의 고유 id

# %%
len(train["VisitNumber"].unique()),train["VisitNumber"].unique()
# Out:
# (95674,
#  array([     5,      7,      8, ..., 191345, 191346, 191347], dtype=int64))

# %%
plt.plot(train['VisitNumber'])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.ylim(0,50)
plt.scatter(train["VisitNumber"], train["TripType"])
plt.show()

# %% [markdown]
# ### Weekday

# %%
len(train["Weekday"].unique()),train["Weekday"].unique()
# Out:
# (7, array(['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday',
#         'Thursday'], dtype=object))

# %%
plt.plot(train['Weekday'])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.ylim(0,50)
plt.scatter(train["Weekday"], train["TripType"])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.ylim(0,50)
sns.boxplot(train["Weekday"], train["TripType"])
plt.show()

# %% [markdown]
# ### ScanCount
# - 상품 구입 수
# - -1 이면 환불

# %%
len(train["ScanCount"].unique()),train["ScanCount"].unique()
# Out:
# (39, array([ -1,   1,   2,   3,   5,   6,   4,  14,  -2,   9,   7,  10,   8,
#          -3,  -5,  11,  16,  -4,  13,  15,  30,  -6,  12,  20, -12,  19,
#          46,  23,  -7,  22,  25,  24,  31,  -9,  51,  17,  18,  71, -10],
#        dtype=int64))

# %%
plt.plot(train['ScanCount'])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.ylim(0,50)
plt.scatter(train["ScanCount"], train["TripType"])
plt.show()

# %%
plt.figure(figsize=(10,10))
# plt.ylim(0,50)
sns.boxplot(train["TripType"], train["ScanCount"])
plt.show()

# %% [markdown]
# ### DepartmentDescription
# - 상품종목

# %%
len(train["DepartmentDescription"].unique()),train["DepartmentDescription"].unique()
# Out:
# (69, array(['FINANCIAL SERVICES', 'SHOES', 'PERSONAL CARE',
#         'PAINT AND ACCESSORIES', 'DSD GROCERY', 'MEAT - FRESH & FROZEN',
#         'DAIRY', 'PETS AND SUPPLIES', 'HOUSEHOLD CHEMICALS/SUPP', nan,
#         'IMPULSE MERCHANDISE', 'PRODUCE', 'CANDY, TOBACCO, COOKIES',
#         'GROCERY DRY GOODS', 'BOYS WEAR', 'FABRICS AND CRAFTS',
#         'JEWELRY AND SUNGLASSES', 'MENS WEAR', 'ACCESSORIES',
#         'HOME MANAGEMENT', 'FROZEN FOODS', 'SERVICE DELI',
#         'INFANT CONSUMABLE HARDLINES', 'PRE PACKED DELI', 'COOK AND DINE',
#         'PHARMACY OTC', 'LADIESWEAR', 'COMM BREAD', 'BAKERY',
#         'HOUSEHOLD PAPER GOODS', 'CELEBRATION', 'HARDWARE', 'BEAUTY',
#         'AUTOMOTIVE', 'BOOKS AND MAGAZINES', 'SEAFOOD', 'OFFICE SUPPLIES',
#         'LAWN AND GARDEN', 'SHEER HOSIERY', 'WIRELESS', 'BEDDING',
#         'BATH AND SHOWER', 'HORTICULTURE AND ACCESS', 'HOME DECOR', 'TOYS',
#         'INFANT APPAREL', 'LADIES SOCKS', 'PLUS AND MATERNITY',
#         'ELECTRONICS', 'GIRLS WEAR, 4-6X  AND 7-14', 'BRAS & SHAPEWEAR',
#         'LIQUOR,WINE,BEER', 'SLEEPWEAR/FOUNDATIONS',
#         'CAMERAS AND SUPPLIES', 'SPORTING GOODS',
#         'PLAYERS AND ELECTRONICS', 'PHARMACY RX', 'MENSWEAR',
#         'OPTICAL - FRAMES', 'SWIMWEAR/OUTERWEAR', 'OTHER DEPARTMENTS',
#         'MEDIA AND GAMING', 'FURNITURE', 'OPTICAL - LENSES', 'SEASONAL',
#         'LARGE HOUSEHOLD GOODS', '1-HR PHOTO', 'CONCEPT STORES',
#         'HEALTH AND BEAUTY AIDS'], dtype=object))

# %%
# object 형식
plt.figure(figsize=(15,15))
# plt.Xlim(0,50)
sns.boxplot(train["TripType"], train["DepartmentDescription"])
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.boxplot(train[train["TripType"]<500]["TripType"], train["DepartmentDescription"])
plt.xlim(0,50)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot(train["TripType"], train["DepartmentDescription"])
plt.xlim(0, 300)
plt.show()

# %%
# DepartmentDescription가 OPTICAL - LENSES일때 TripType이 5인것만 있다.
train[train["DepartmentDescription"] == "OPTICAL - LENSES"]["TripType"][train[train["DepartmentDescription"] == "OPTICAL - LENSES"]["TripType"] != 5]
# Out:
# Series([], Name: TripType, dtype: int64)

# %% [markdown]
# ### FinelineNumber
# - walmart가 자체적으로 부여한 카테고리 값

# %%
len(train["FinelineNumber"].unique()),train["FinelineNumber"].unique()
# Out:
# (5196, array([1000., 8931., 4504., ..., 8257., 4314., 7130.]))

# %%
plt.figure(figsize=(10,10))
plt.ylim(0,50)
plt.scatter(train["FinelineNumber"], train["TripType"])
plt.show()

# %% [markdown]
# ### FinelineNumber와 DepartmentDescription의 상관관계

# %%
plt.figure(figsize=(15,15))
sns.barplot(train['FinelineNumber'], train['DepartmentDescription'])
plt.show()
